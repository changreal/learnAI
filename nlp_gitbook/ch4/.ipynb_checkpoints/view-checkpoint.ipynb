# %%
import networkx as nx
import matplotlib.pyplot as plt
#有向图
DG = nx.DiGraph()   # 创建一个空的有向图
#添加一个节点
DG.add_node('A')
#作图，设置节点名显示,节点大小，节点颜色
nx.draw(DG,with_labels=True,node_size=900,node_color = 'green')
plt.show()

# %%
#有向图
DG = nx.DiGraph()
#添加一个节点
DG.add_node('A')
DG.add_node('B')
#添加边，有方向，A-->B
DG.add_edge('A','B')
#作图，设置节点名显示,节点大小，节点颜色
nx.draw(DG,with_labels=True,node_size=900,node_color = 'green')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 设置matplotlib正常显示中文,用黑体显示中文
plt.rcParams['font.sans-serif']=['SimHei']  
plt.rcParams['axes.unicode_minus']=False 
colors = ['red', 'green', 'blue', 'yellow']

#有向图
DG = nx.DiGraph()
#一次性添加多节点，输入的格式为列表
DG.add_nodes_from(['甘肃', '武威', '兰州', '张掖','凉州区'])
#添加边，数据格式为列表
DG.add_edges_from([('甘肃', '武威'), ('甘肃', '兰州'), ('甘肃','张掖'),('武威','凉州区')])
#作图，设置节点名显示,节点大小，节点颜色
nx.draw(DG,with_labels=True, node_size=900, node_color = colors)
plt.show()

# %%
import pandas as pd
import numpy as np
import jieba
import matplotlib.pyplot as plt 
# %matplotlib inline
import matplotlib

dir = "./"
columns = ['std_id','class','name','classroom','label_1','label_2','label_3','label_4','time','label_5']
df = pd.read_csv(dir + "nd_course_schedule_info.csv",sep='\t',names=columns)

# %%
classes= df['class'].values.tolist()
classrooms=df['classroom'].values.tolist()
nodes = list(set(classes + classrooms))
# print(nodes)
weights = [(df.loc[index,'class'],df.loc[index,'classroom'])for index in df.index]   
weights =  list(set(weights))
# 设置matplotlib正常显示中文
plt.rcParams['font.sans-serif']=['SimHei']   # 用黑体显示中文
plt.rcParams['axes.unicode_minus']=False 
colors = ['red', 'green', 'blue', 'yellow']
#有向图
DG = nx.DiGraph()
#一次性添加多节点，输入的格式为列表
DG.add_nodes_from(nodes)
#添加边，数据格式为列表
DG.add_edges_from(weights)
#作图，设置节点名显示,节点大小，节点颜色
nx.draw(DG,with_labels=True, node_size=1000, node_color = colors)
plt.show()
# Out:
# ['旧教学楼102', nan, '兽医外科学', '人际传播（双学位）', '旧教学楼303', '旧教学楼1414', '旧教学楼416', '企业营销与市场开发', '旧教学楼2319', '蛋品工艺学', '农业生物环境原理', '二教2210', '战略管理', '体育部乒乓球室 ', '公主楼106', '无线传感器技术', '奥运副馆羽毛球场地', '一教207', '生物信息学', '结构生物学', '旧教学楼219', '和园餐厅207', '财务会计信息系统', '三教185', '三教电102', '二教214', '健美操（2）', '旧教学楼385', '微生物生理学实验', '水资源利用与管理', '葡萄酒工程原理', '乒乓球提高', '二手车评估', '果蔬采后病理', '新教学楼2121', '一教105', '体育场地足球场', '旧教学楼382', '信电楼电121', '艺术中心第三舞蹈室', '食品工艺学概论', '旧教学楼103', '食品防伪与鉴别', '旧教学楼195', '灌溉排水工程学', '一号公寓214', '市场营销（双学位）', '生物多样性导论', '维生素与健康', '最优化方法', '特禽生产学', '伦理学基础', '一教190', '操作系统', '主楼2221', '新教学楼2319', '主楼490', '行政法与行政诉讼法', '主楼185', '计网中心训练中心三层机房', '有机农业概论', '三教2223', '计网中心2223', '作物育种学', '公共财政学（双学位）', '新教学楼207', '三教489', '机械设计', '新动科楼饲料分析室', '基因工程实验技术', '土壤、植物与环境分析实验（上）', '旧教学楼2117', '技术经济学', '新教学楼195', '二教116', '三教405', '兽医病理解剖学', '二教2123', '植物生理学', '蔬菜栽培学各论', '190', '项目管理', '城乡与区域规划原理', '发酵工程实验', '基础摄影（双学位）', '进化生物学', '三教505', '项目投资分析（双学位）', '绿色化学', '计网中心114', '网页制作', '旧教学楼2121', '二教三教二层物理演示室', '植保专业实验（3）', '多媒体技术', '理学楼444', '光电技术原理', '食品病原学实验', '信息系统设计与分析', '工程测试技术', '西方政治制度', '国际法', '理学院楼理学院机房', '管理咨询实务', '三教256', '计算机图形学', '二教307', '体育场地操场', '细胞生物学', '485', '舞蹈基础3', '弦乐基础3', '三教214', '工厂设计', '农业信息技术实验', '旧教学楼516', '体育部主楼东1-2号网球场', '货币银行学（双学位）', '单片机原理', '机电数控技术', '观赏植物概论', '三维图形程序设计', '财政学', '三教507', '园艺学实验（3）', '新教学楼214', '饲料添加剂', '新动科楼0143', '新教学楼2203', '计算机网络B实验', '工院楼工251', '新教学楼304', '奥运副馆跆拳道馆', '一教119', '管理学基础', '一教124', '农学楼295', '饮食、营养与慢性疾病', '土壤学基础与土壤地理', '三教电109', '新教学楼一区217', '保险学', '新教学楼171', '522', '管乐演奏艺术B', '生物化学B实验', '种子加工与检验', '农学楼428', '三教工209', '东区8号楼三层琴房', '微生物学实验', '工程项目管理', '女性学专题', '主楼310', '兽医内科学', '土壤与农作学', '设计与制图基础A', '软件工程实验', '生物化学B', '旧教学楼295', '软件工程课程设计', '工院楼工254', '一教310', '一教185', '食品大楼感官评价室440', '舞蹈表演4', '单片机原理与应用B实验', '主楼201', '农学楼一层135机房', '植物营养学', '高频电子电路实验', '新教学楼389', '奥运馆主馆跆拳道馆', '兽医产科学', '中国新闻传播史（双学位）', 'Web数据库设计与管理', '宏观经济学：原理与热点政策', '田间技术实验(下)', '兽医免疫学', '旧教学楼485', '新教学楼428', '三教228', '高级会计学', '园艺植物营养学', '新教学楼187', '兽医统计学', '待定1', '控制工程基础A', '二教228', '实验室安全防护', '比较基因学及分子进化', '国际经济法', '新教学楼490', '二教315', '305', '二教128', '戏剧表演3', 'VB程序设计', '信电楼电103', '新教学楼2106', '东区8号楼二层音乐教室', '二教187', '植物病害生物防治学', '中国农业发展史', '种子病理学', '一教510', '317', '计网中心105', '三教516', '旧教学楼202', '二教202', '旧教学楼209', '液压与气压传动', '二教295', '普通昆虫学实验', '管乐基础4', '二教108', '主楼410', '体育部篮球场02', '行政管理学', '电视新闻与纪录片（双学位）', '旧教学楼187', '三教128', '482', '385', '主楼212', '园林花卉学', '信电楼电109', '三教2123', '足球（1）', '285', '反贫困的理论与实践', '精度与测量', '二教103', '农业生态学', '新教学楼117', '奥运副馆乒乓球场地', '二教201', '体育部主楼东高尔夫练习场地', '主楼106', '植物抗虫性基因工程', '一教206', '新教学楼2215', '信电楼210', '新教学楼106', '农学概论', '新教学楼510', '三教295', '旧教学楼112', '中国民族民间音乐赏析', '水利工程施工', '动医楼418', '主楼409', '二教124', '单片机原理实验', '算法设计与分析实验', '旧教学楼饲料分析室', '企业管理（双学位）', '三教218', '汽车文化', '三教108', '计网中心185', '一教304', '工院楼405', '市场营销学', '马术与马文化', '电磁场与电磁波', '设施栽培学基础', '个人理财', '兽医公共卫生学', '信电楼2007', '环境与发展', '土力学与地基基础B', '机械化农业生产实验', '三教118', '计算机测控技术', '流体机械结构与装拆实验', '昆虫分类学', '科学园205', '分子植物病理学入门', '东区8号楼201', '微波工程基础', '一教505', '207', '新教学楼1411', '现代企业制度', '主楼420', '工院楼218', '三教106', '工院楼工263', '焙烤食品工艺学', '空间分析实验', '二教105', '科学园203', '旧教学楼304', '农业机械与设备', '计网中心电108', '三教487', '结构力学Ⅰ', '新教学楼2101', '奥运馆主馆一层舞蹈教室', '食品包装学', '旧教学楼285', '试验设计与数据处理', 'HACCP理论与实施', '旧教学楼2103', '运动场草坪', '机械制造工程学', '理学楼358', '电子媒体技术基础', '西方经济学（双学位）', '二教121', '新教学楼185', '新教学楼2117', 'Java程序设计', '民乐基础3', '食品大楼食品楼实验室', '一号公寓106', '单片机原理与应用B', '养鱼学', '食品卫生学', '农作物概论', '葡萄酒庄设计与管理', '资源环境法', '一教108', '烘焙食品营养与文化', '优质畜禽产品管理规范', '主楼219', '艺术中心一层舞蹈教室', '旧教学楼205', '旧教学楼489', '三教211', '兽医药理学', '油脂加工工艺学', '旧教学楼306', '资源环境信息技术', '一教402', '谱学基础', '二教112', '艺术中心1', '市场营销', '草地学实验', '信电楼301', '影视视听艺术与表达技巧', '一教211', '灌排机械与泵站课程设计', '新教学楼303', '主楼112', '武术散手（2）', '农业法学', '旧教学楼310', '三教304', '水文学原理及建模', '水力机械测试技术', '试验设计与生物统计', '知识产权法', '银行法', '三教电115', '新教学楼一区227', '外国新闻传播史（双学位）', '旧教学楼289', '一教1', '主楼401', '计网中心2221', '新教学楼290', '音乐剧欣赏', '城市昆虫', '计量经济学A\u3000', '园艺楼2123', '土地管理学', '工院楼工206', '日语二外（上）', '农学专业实验（1）', '作物育种工程学', '旧教学楼2217', '苜蓿生产学', '农学楼219', '旧教学楼 ...

# %%
import pandas as pd

# %%
pd.to_datetime("")
